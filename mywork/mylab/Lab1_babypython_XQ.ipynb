# %% [markdown]
# # Lab1 Babypython
#
# Lab1 of Harvard CS109 Data Science: A quick run-through of some python syntax.

# %%
# %%bash
# python --version #Check my default anaconda environment and python version:
# Out:
# Python 2.7.11 :: Anaconda 2.1.0 (64-bit)

# %% [markdown]
# In my default Anaconda environment, **seaborn** is not installed, and the old version Ipython notebook needs to be replaced with jupyter noebook
#
# **seaborn**
# Lab1 needs `seaborn` package, which was not installed on my anaconda python distribution. In my unbuntu terminal use the following conda command to install `seaborn`:
#
# `conda install seaborn`
#
# **jupyter notebook**
# CS109 use jupyter notebook instead of ipython notebook. Install jupyter notebook:
#
# ` conda isntall jupyter notebook`

# %%
# %%bash
# jupyter notebook --version  # check that jupyter notebook version
# Out:
# 4.1.0

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# set up pandas table display
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)

# import seaborn
import seaborn as sns

# %% [markdown]
# ** Listness**
#
# The way how python create/access sequence like data structures, and files, and a general notion of iterator.

# %% [markdown]
# ** enumerate vs zip **

# %%
alist = [1, 2, 3, 4]

# enumerate
for index, value in enumerate(alist):
    print index, value
# Out:
# 0 1
# 1 2
# 2 3
# 3 4

# %%
# zip
list1 = ['a', 'b', 'c', 'd']
list2 = [1, 2, 3, 4]
list3 = zip(list1, list2)
list3
# Out:
# [('a', 1), ('b', 2), ('c', 3), ('d', 4)]

# %% [markdown]
# ** open files**
# Open files behave like lists

# %%
# %pwd
# Out:
# u'/home/johnx/Documents/Github/CS109/2015lab1_XQ'

# %%
# %%bash
# cd ../
# ls -F
# Out:
# 2015lab1/
# 2015lab1_XQ/

# %%
# The length of a string can be returned by len() function
# note: space is also counted.
len("a b c")
# Out:
# 5

# %%
# poor code as we do not close the file
# the object returned by open a file
# is like a list of strings, each string in the list
# stores a line of the opened file. 
# The following code returnes the length of each line
# of the hamlet.txt file
linelengths = [len(line) for line in open("../2015lab1/hamlet.txt")]
print linelengths
# Out:
# [9, 27, 2, 24, 2, 2, 2, 2, 22, 2, 28, 60, 29, 28, 27, 22, 22, 24, 25, 18, 24, 11, 21, 20, 22, 32, 10, 28, 31, 12, 22, 27, 2, 51, 32, 2, 67, 13, 2, 18, 2, 2, 2, 8, 2, 50, 2, 49, 2, 6, 14, 2, 7, 45, 2, 6, 21, 2, 7, 11, 2, 6, 5, 2, 7, 41, 2, 6, 53, 2, 7, 48, 25, 2, 6, 27, 2, 7, 23, 2, 6, 19, 39, 46, 2, 7, 48, 2, 32, 2, 6, 25, 2, 6, 27, 2, 7, 22, 2, 6, 30, 24, 2, 7, 24, 22, 2, 9, 2, 6, 18, 2, 6, 6, 25, 2, 6, 17, 2, 6, 45, 2, 6, 47, 2, 6, 22, 2, 6, 36, 42, 48, 38, 45, 37, 42, 2, 6, 32, 2, 6, 18, 41, 42, 31, 2, 6, 20, 41, 2, 6, 20, 51, 51, 43, 30, 2, 6, 51, 2, 23, 2, 6, 48, 2, 6, 43, 2, 6, 47, 2, 6, 49, 2, 6, 23, 2, 6, 23, 2, 6, 50, 42, 40, 54, 2, 6, 17, 2, 6, 22, 2, 6, 42, 2, 15, 2, 6, 33, 2, 6, 46, 42, 22, 2, 6, 41, 38, 19, 2, 6, 26, 2, 6, 25, 36, 40, 45, 42, 15, 2, 6, 48, 47, 2, 6, 48, 44, 48, 2, 6, 49, 47, 43, 43, 41, 50, 43, 46, 50, 30, 2, 6, 13, 47, 42, 44, 45, 53, 53, 53, 36, 50, 45, 39, 43, 35, 50, 39, 49, 36, 47, 41, 39, 48, 42, 39, 46, 45, 41, 50, 44, 2, 6, 37, 47, 49, 45, 2, 6, 
# ...

# %%
sum(linelengths), np.mean(linelengths), np.median(linelengths), np.std(linelengths)
# Out:
# (180718, 26.69394387001477, 26.0, 21.029872021427462)

# %%
# Access text file word by word instead of line by line

# hamletfile- the file object
hamletfile = open("../2015lab1/hamlet.txt")
print(type(hamletfile)) #check the type of hamletfile object

# use file.read() method to grab the content of the file
# and return it as string 
hamlettext = hamletfile.read()
print(type(hamlettext)) #check the type of hamlettext

hamletfile.close() # remember to close the file

#hamlettext is a string, so we can use string methods 
#split with no arguments splits on whitespace
hamlettokens = hamlettext.split() 
len(hamlettokens)
# Out:
# <type 'file'>
# <type 'str'>
# 31659

# %%
astring = "This a string for testing the string.split() method. \
           I want to see how it works"
print(astring.split())
len(astring.split())
# Out:
# ['This', 'a', 'string', 'for', 'testing', 'the', 'string.split()', 'method.', 'I', 'want', 'to', 'see', 'how', 'it', 'works']
# 15

# %% [markdown]
# One can use the with syntax which cretaes a context. The file closing is then done automatically for us.

# %%
with open("../2015lab1/hamlet.txt") as hamletfile:
    hamlettext = hamletfile.read()
    hamlettokens = hamlettext.split()
    print len(hamlettokens)
# Out:
# 31659

# %% [markdown]
# ** range vs xrange **
#
# range and xrange get the list of integers upto N. But xrange behaves like an iterator. The reason for this is that there is no point generaing all os a million integers. We can just add 1 to the previous one and save memory. So we trade off storage for computation.

# %% [markdown]
# ## Dictionaries
#
# These are the bread and butter. You will use them a lot. They even duck like lists. But be careful how.

# %%
adict={'one':1, 'two': 2, 'three': 3}
print adict
print [i for i in adict]
print [(k,v) for k,v in adict.items()]
print adict.values()
# Out:
# {'three': 3, 'two': 2, 'one': 1}
# ['three', 'two', 'one']
# [('three', 3), ('two', 2), ('one', 1)]
# [3, 2, 1]

# %%
# Creat dictionary with dictionary comprehension
# the syntax is the similar to list comprehension
list1 = ['a', 'b', 'c', 'd']
list2 = [1, 2, 3, 4]
mydict = {k:v for (k,v) in zip(list1, list2)}
mydict
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# #### Conversion of dictionary to json

# %%
import json

# %%
s = json.dumps(mydict)
print s
# Out:
# {"a": 1, "c": 3, "b": 2, "d": 4}

# %%
json.loads(s)
# Out:
# {u'a': 1, u'b': 2, u'c': 3, u'd': 4}

# %% [markdown]
# ## Functions
#
# Functions are even more the bread and butter. You'll see them as methods on objects, or standing alone by themselves.
#
# In Python, functions are "first-class". This is just a fancy way of saying, you can pass functions to other functions

# %%
def sum_of_anything(x, y, f):
    print x, y, f
    return (f(x)+f(y))
sum_of_anything(-3, 4, abs)
# Out:
# -3 4 <built-in function abs>
# 7

# %% [markdown]
# Python functions can have positional arguments and keyword arguments. Positional arguments are stored in a tuple, and keyword arguments in a dictionary. Note the "starred" syntax

# %%
def f(a, b, *posargs, **dictargs):
    print "got", a, b, posargs, dictargs
    return a
print f(1, 3)
print f(1, 3, 4, d = 1, c = 2)
# Out:
# got 1 3 () {}
# 1
# got 1 3 (4,) {'c': 2, 'd': 1}
# 1

# %% [markdown]
# ### Exercise
# create a dictionary with keys the integers upto and including 10, and values the cubes of these dictionaries

# %%
dict1 = {k:v for (k, v) in zip(range(11), [x**3 for x in range(11)])}
dict1
# Out:
# {0: 0,
#  1: 1,
#  2: 8,
#  3: 27,
#  4: 64,
#  5: 125,
#  6: 216,
#  7: 343,
#  8: 512,
#  9: 729,
#  10: 1000}

# %%
dict1[:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-6eec1b5415cf> in <module>()
# ----> 1 dict1[:5]
#
# TypeError: unhashable type

# %%
dict1[3]
# Out:
# 27

# %%
dict1[3]+dict1[4]
# Out:
# 91

# %% [markdown]
# ## Summary

# %%
#Lets see what hamlet gives us. We convert all words to lower-case
hamletlctokens = [word.lower() for word in hamlettokens]
hamletlctokens.count("thou") #count method of list
# Out:
# 95

# %% [markdown]
# **set for creating unique sequence**
# We then find a unique set of words using python's set data structure. We count how often those words occured using the count method on lists.

# %%
alist = ['a', 'b', 'c', 'd', 'a', 'd', 'e']
aset = set(alist)
print aset
# Out:
# set(['a', 'c', 'b', 'e', 'd'])

# %%
uniquelctokens = set(hamletlctokens)

# %%
# count the appearances of each unique word
# ans store them in a dictonary in the format of
# word : number of apperance pairs
tokendict = {}
for ut in uniquelctokens:
    tokendict[ut] = hamletlctokens.count(ut)

# find the 100 most used words
L = sorted(tokendict.iteritems(), key = lambda (k,v):v, reverse = True)[:100]
L
# Out:
# [('the', 1136),
#  ('and', 943),
#  ('to', 720),
#  ('of', 667),
#  ('a', 527),
#  ('my', 512),
#  ('i', 510),
#  ('in', 420),
#  ('you', 412),
#  ('ham.', 358),
#  ('that', 337),
#  ('it', 324),
#  ('is', 320),
#  ('his', 295),
#  ('not', 270),
#  ('with', 264),
#  ('this', 250),
#  ('your', 241),
#  ('for', 231),
#  ('but', 228),
#  ('as', 216),
#  ('he', 202),
#  ('be', 201),
#  ('what', 183),
#  ('have', 174),
#  ('will', 149),
#  ('so', 143),
#  ('me', 142),
#  ('we', 132),
#  ('do', 128),
#  ('are', 126),
#  ('him', 122),
#  ('our', 119),
#  ('king.', 113),
#  ('by', 111),
#  ('hor.', 110),
#  ('or', 109),
#  ('if', 109),
#  ('on', 109),
#  ('no', 107),
#  ('shall', 106),
#  ('thou', 95),
#  ('all', 95),
#  ('from', 95),
#  ('they', 93),
#  ('let', 92),
#  ('good', 88),
#  ('at', 86),
#  ('thy', 86),
#  ('pol.', 86),
#  ('how', 84),
#  ('most', 82),
#  ('lord,', 81),
#  ('her', 76),
#  ('more', 76),
#  ('queen.', 76),
#  ('like', 75),
#  ('would', 74),
#  ('was', 73),
# ...

# %%
topfreq = L[:20] # The mostly showed 20 words
print topfreq
pos = np.arange(len(topfreq))
plt.bar(pos,  [e[1] for e in topfreq]);
plt.xticks(pos+0.4, [e[0] for e in topfreq]);
# Out:
# [('the', 1136), ('and', 943), ('to', 720), ('of', 667), ('a', 527), ('my', 512), ('i', 510), ('in', 420), ('you', 412), ('ham.', 358), ('that', 337), ('it', 324), ('is', 320), ('his', 295), ('not', 270), ('with', 264), ('this', 250), ('your', 241), ('for', 231), ('but', 228)]
